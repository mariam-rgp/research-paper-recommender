# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df=pd.read_csv('/home/mariam/Projects/research-paper-recommender/data/arxiv_data_210930-054931.csv')

# %%
df.head()
# Out:
#                            terms  \
# 0                      ['cs.LG']
# 1             ['cs.LG', 'cs.AI']
# 2  ['cs.LG', 'cs.CR', 'stat.ML']
# 3             ['cs.LG', 'cs.CR']
# 4                      ['cs.LG']
#
#                                               titles  \
# 0  Multi-Level Attention Pooling for Graph Neural...
# 1  Decision Forests vs. Deep Networks: Conceptual...
# 2  Power up! Robust Graph Convolutional Network v...
# 3  Releasing Graph Neural Networks with Different...
# 4  Recurrence-Aware Long-Term Cognitive Network f...
#
#                                            abstracts
# 0  Graph neural networks (GNNs) have been widely ...
# 1  Deep networks and decision forests (such as ra...
# 2  Graph convolutional networks (GCNs) are powerf...
# 3  With the increasing popularity of Graph Neural...
# 4  Machine learning solutions for pattern classif...

# %%
df.shape
# Out:
# (56181, 3)

# %%
df.columns
# Out:
# Index(['terms', 'titles', 'abstracts'], dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 56181 entries, 0 to 56180
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   terms      56181 non-null  str
#  1   titles     56181 non-null  str
#  2   abstracts  56181 non-null  str
# dtypes: str(3)
# memory usage: 1.3 MB

# %%
df.isnull().sum()
# Out:
# terms        0
# titles       0
# abstracts    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(15054)

# %%
df.nunique()
# Out:
# terms         3402
# titles       41105
# abstracts    41115
# dtype: int64

# %%
df[df.duplicated(keep=False)].head(10)
# Out:
#                            terms  \
# 0                      ['cs.LG']
# 1             ['cs.LG', 'cs.AI']
# 2  ['cs.LG', 'cs.CR', 'stat.ML']
# 3             ['cs.LG', 'cs.CR']
# 4                      ['cs.LG']
# 5           ['cs.LG', 'stat.ML']
# 6                      ['cs.LG']
# 7           ['cs.LG', 'stat.ML']
# 8                      ['cs.LG']
# 9             ['cs.LG', 'cs.AI']
#
#                                               titles  \
# 0  Multi-Level Attention Pooling for Graph Neural...
# 1  Decision Forests vs. Deep Networks: Conceptual...
# 2  Power up! Robust Graph Convolutional Network v...
# 3  Releasing Graph Neural Networks with Different...
# 4  Recurrence-Aware Long-Term Cognitive Network f...
# 5                            Lifelong Graph Learning
# 6  Bayesian graph convolutional neural networks v...
# 7  Understanding and Resolving Performance Degrad...
# 8  Edge-augmented Graph Transformers: Global Self...
# 9         Variational Graph Normalized Auto-Encoders
#
# ...

# %%
df['titles'].value_counts().head(10)
# Out:
# titles
# Learning Local Neighboring Structure for Robust 3D Shape Representation                              7
# Point Transformer                                                                                    7
# Transformers in Vision: A Survey                                                                     7
# Deep Reinforcement Learning: An Overview                                                             7
# Learnable Hypergraph Laplacian for Hypergraph Learning                                               6
# Graph Representation Learning via Graphical Mutual Information Maximization                          6
# A Survey on Machine Learning Techniques for Auto Labeling of Video, Audio, and Text Data             6
# Applications of Deep Neural Networks                                                                 6
# Ensemble Augmentation for Deep Neural Networks Using 1-D Time Series Vibration Data                  6
# ...

# %%
title = df['titles'].value_counts().index[0]
title
# Out:
# 'Learning Local Neighboring Structure for Robust 3D Shape Representation'

# %%
df[df['titles'] == title][['terms', 'titles', 'abstracts']]
# Out:
#                                terms  \
# 162    ['cs.CV', 'cs.LG', 'eess.IV']
# 990    ['cs.CV', 'cs.LG', 'eess.IV']
# 15261  ['cs.CV', 'cs.LG', 'eess.IV']
# 25685  ['cs.CV', 'cs.LG', 'eess.IV']
# 35547  ['cs.CV', 'cs.LG', 'eess.IV']
# 48434  ['cs.CV', 'cs.LG', 'eess.IV']
# 53908  ['cs.CV', 'cs.LG', 'eess.IV']
#
#                                                   titles  \
# 162    Learning Local Neighboring Structure for Robus...
# 990    Learning Local Neighboring Structure for Robus...
# 15261  Learning Local Neighboring Structure for Robus...
# 25685  Learning Local Neighboring Structure for Robus...
# 35547  Learning Local Neighboring Structure for Robus...
# 48434  Learning Local Neighboring Structure for Robus...
# 53908  Learning Local Neighboring Structure for Robus...
#
#                                                abstracts
# 162    Mesh is a powerful data structure for 3D shape...
# 990    Mesh is a powerful data structure for 3D shape...
# ...

# %%
df[df['titles'] == title]['abstracts'].nunique()
# Out:
# 1

# %% [markdown]
# We found that some papers appear multiple times in the dataset. For example, the paper "Learning Local Neighboring Structure for Robust 3D Shape Representation" appeared seven times with exactly the same terms, title, and abstract.

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (41127, 3)

# %%
df['terms'].nunique()
# Out:
# 3402

# %%
df[['titles', 'abstracts']].describe()
# Out:
#                                                    titles  \
# count                                               41127
# unique                                              41105
# top     Learnable Hypergraph Laplacian for Hypergraph ...
# freq                                                    2
#
#                                                 abstracts
# count                                               41127
# unique                                              41115
# top     HyperGraph Convolutional Neural Networks (HGCN...
# freq                                                    2

# %%
df['title length']=df['titles'].str.split().str.len()
df['abstract length']=df['abstracts'].str.split().str.len()

# %%
df[['title length', 'abstract length']].describe()
# Out:
#        title length  abstract length
# count  41127.000000     41127.000000
# mean       8.901476       171.456975
# std        3.040075        45.950679
# min        1.000000         5.000000
# 25%        7.000000       140.000000
# 50%        9.000000       169.000000
# 75%       11.000000       201.000000
# max       30.000000       498.000000

# %%
df[['titles', 'abstracts']].sample(5, random_state=42)
# Out:
#                                                   titles  \
# 28691       GAN-based Priors for Quantifying Uncertainty
# 29603  Bidirectional Conditional Generative Adversari...
# 11048  Meta Reinforcement Learning with Distribution ...
# 19930  xYOLO: A Model For Real-Time Object Detection ...
# 17046  ContraGAN: Contrastive Learning for Conditiona...
#
#                                                abstracts
# 28691  Bayesian inference is used extensively to quan...
# 29603  Conditional Generative Adversarial Networks (c...
# 11048  In this paper, we propose a novel meta-learnin...
# 19930  With the emergence of onboard vision processin...
# 17046  Conditional image generation is the task of ge...

# %%
df['text'] = df['titles'] + ' ' + df['abstracts']

# %%
df[['titles', 'abstracts', 'text']].head(2)
# Out:
#                                               titles  \
# 0  Multi-Level Attention Pooling for Graph Neural...
# 1  Decision Forests vs. Deep Networks: Conceptual...
#
#                                            abstracts  \
# 0  Graph neural networks (GNNs) have been widely ...
# 1  Deep networks and decision forests (such as ra...
#
#                                                 text
# 0  Multi-Level Attention Pooling for Graph Neural...
# 1  Decision Forests vs. Deep Networks: Conceptual...

# %%
df.to_csv("../data/arxiv_cleaned.csv", index=False)
